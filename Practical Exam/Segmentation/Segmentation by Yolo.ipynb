# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt

# Load a model (YOLOv8)
model = YOLO("yolov8n-seg.pt")  # Make sure the path is correct

# Predict with the model (using an image URL)

# %%
import os 
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# %%
results = model("D:\Term1th4\Computer_Vision\Sections\sec7\dog.jpeg")  # This URL points to an image of a bus

result_img = results[0].plot()
plt.imshow(result_img)
plt.axis('off')
plt.show()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\Taha Tarek\AppData\Local\Temp\ipykernel_19096\1325583562.py:1: SyntaxWarning: invalid escape sequence '\T'
#   results = model("D:\Term1th4\Computer_Vision\Sections\sec7\dog.jpeg")  # This URL points to an image of a bus
# image 1/1 D:\Term1th4\Computer_Vision\Sections\sec7\dog.jpeg: 480x640 1 dog, 49.9ms
# Speed: 4.0ms preprocess, 49.9ms inference, 125.8ms postprocess per image at shape (1, 3, 480, 640)

# %%
results = model("D:\Term1th4\Computer_Vision\Sections\sec7\seg.mp4",save= True)  # This URL points to an image of a bus

result_img = results[0].plot()
plt.imshow(result_img)
plt.axis('off')
plt.show()
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\Taha Tarek\AppData\Local\Temp\ipykernel_19096\31397933.py:1: SyntaxWarning: invalid escape sequence '\T'
#   results = model("D:\Term1th4\Computer_Vision\Sections\sec7\seg.mp4",save= True)  # This URL points to an image of a bus
# ...
